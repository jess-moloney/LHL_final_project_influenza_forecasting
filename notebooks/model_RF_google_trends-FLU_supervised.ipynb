# %% [markdown]
# # Imports

# %%
import pickle
import pandas as pd
import numpy as np

# regression models
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

# plotting
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
plt.rcParams['figure.figsize'] = [20, 10]

# custom functions
import sys
sys.path.append(r"C:\Users\User\Documents\projects\LHL_final_project_influenza_forecasting\src")
from rf_model import *

# %% [markdown]
# # Datasets

# %%
df_flu_symptoms_pre_COVID = pickle.load(open(r"..\data\google_trend\df_flu_symptoms_pre_COVID.pkl", "rb" ))
df_flu_symptoms= pickle.load(open(r"..\data\google_trend\df_flu_symptoms.pkl", "rb" ))

# %% [markdown]
# # Random Forest - pre-COVID

# %%
for i in range(1,5):
    results_matrix = rf_model(data=df_flu_symptoms_pre_COVID, weeks_to_predict=i, max_depth=2, df_name='df_flu_symptoms_pre_COVID')
# Out:
# Shape of train_X: (234, 11)
# Shape of train_y: (234, 1)
# Shape of test_X: (1, 11)
# Shape of test_y: (1, 1)
# Shape of train_X: (233, 11)
# Shape of train_y: (233, 1)
# Shape of test_X: (2, 11)
# Shape of test_y: (2, 1)
# Shape of train_X: (232, 11)
# Shape of train_y: (232, 1)
# Shape of test_X: (3, 11)
# Shape of test_y: (3, 1)
# Shape of train_X: (231, 11)
# Shape of train_y: (231, 1)
# Shape of test_X: (4, 11)
# Shape of test_y: (4, 1)

# %%
results_matrix
# Out:
#   Model                    Dataset Weeks-ahead Forecast    MSE_train  \
# 0    rf   df_COVID_terms_pre_COVID                    1  1284097.656
# 0    rf   df_COVID_terms_pre_COVID                    2  1281098.556
# 0    rf   df_COVID_terms_pre_COVID                    3  1263787.214
# 0    rf   df_COVID_terms_pre_COVID                    4  1243927.645
# 0    rf             df_COVID_terms                    1   983371.642
# 0    rf             df_COVID_terms                    2   958233.029
# 0    rf             df_COVID_terms                    3   951315.944
# 0    rf             df_COVID_terms                    4   952351.794
# 0    rf  df_flu_symptoms_pre_COVID                    1   208978.844
# 0    rf  df_flu_symptoms_pre_COVID                    2   207860.258
# 0    rf  df_flu_symptoms_pre_COVID                    3   208773.141
# 0    rf  df_flu_symptoms_pre_COVID                    4   214788.783
#
#   RMSE_train MAE_train      MSE_test RMSE_test  MAE_test
# 0    1133.18   863.896    202574.741   450.083   450.083
# 0   1131.856   864.074    261765.646    511.63   510.064
# 0   1124.183   863.332    144140.878   379.659   334.898
# 0   1115.315   861.737    327080.118   571.909   387.797
# 0    991.651   682.959  18217137.404  4268.154  4268.154
# 0    978.894    672.53  15902387.801   3987.78  3933.119
# 0    975.354   670.339  12901224.544  3591.827  3367.181
# 0    975.885   670.829    9855763.71  3139.389  2656.231
# 0    457.142   286.683    435719.268    660.09    660.09
# 0    455.917   283.864    424747.631   651.727   650.498
# 0    456.917   285.484    295923.824   543.989   513.751
# 0    463.453   288.606    243593.986   493.552   468.207

# %% [markdown]
# # Random Forest - post-COVID

# %%
for i in range(1,5):
    results_matrix = rf_model(data=df_flu_symptoms, weeks_to_predict=i, max_depth=2, df_name='df_flu_symptoms')
# Out:
# Shape of train_X: (376, 11)
# Shape of train_y: (376, 1)
# Shape of test_X: (1, 11)
# Shape of test_y: (1, 1)
# Shape of train_X: (375, 11)
# Shape of train_y: (375, 1)
# Shape of test_X: (2, 11)
# Shape of test_y: (2, 1)
# Shape of train_X: (374, 11)
# Shape of train_y: (374, 1)
# Shape of test_X: (3, 11)
# Shape of test_y: (3, 1)
# Shape of train_X: (373, 11)
# Shape of train_y: (373, 1)
# Shape of test_X: (4, 11)
# Shape of test_y: (4, 1)

# %%
results_matrix
# Out:
#   Model                    Dataset Weeks-ahead Forecast    MSE_train  \
# 0    rf   df_COVID_terms_pre_COVID                    1  1284097.656
# 0    rf   df_COVID_terms_pre_COVID                    2  1281098.556
# 0    rf   df_COVID_terms_pre_COVID                    3  1263787.214
# 0    rf   df_COVID_terms_pre_COVID                    4  1243927.645
# 0    rf             df_COVID_terms                    1   983371.642
# 0    rf             df_COVID_terms                    2   958233.029
# 0    rf             df_COVID_terms                    3   951315.944
# 0    rf             df_COVID_terms                    4   952351.794
# 0    rf  df_flu_symptoms_pre_COVID                    1   208978.844
# 0    rf  df_flu_symptoms_pre_COVID                    2   207860.258
# 0    rf  df_flu_symptoms_pre_COVID                    3   208773.141
# 0    rf  df_flu_symptoms_pre_COVID                    4   214788.783
# 0    rf            df_flu_symptoms                    1     418065.0
# 0    rf            df_flu_symptoms                    2   426016.399
# 0    rf            df_flu_symptoms                    3   426280.635
# 0    rf            df_flu_symptoms                    4   417719.063
#
#   RMSE_train MAE_train      MSE_test RMSE_test  MAE_test
# 0    1133.18   863.896    202574.741   450.083   450.083
# 0   1131.856   864.074    261765.646    511.63   510.064
# 0   1124.183   863.332    144140.878   379.659   334.898
# 0   1115.315   861.737    327080.118   571.909   387.797
# 0    991.651   682.959  18217137.404  4268.154  4268.154
# 0    978.894    672.53  15902387.801   3987.78  3933.119
# 0    975.354   670.339  12901224.544  3591.827  3367.181
# 0    975.885   670.829    9855763.71  3139.389  2656.231
# 0    457.142   286.683    435719.268    660.09    660.09
# 0    455.917   283.864    424747.631   651.727   650.498
# 0    456.917   285.484    295923.824   543.989   513.751
# 0    463.453   288.606    243593.986   493.552   468.207
# 0    646.579   407.025  17495867.925  4182.806  4182.806
# 0    652.699   406.017  15364323.946  3919.735  3864.112
# 0    652.902   402.038  11667394.703  3415.757  3178.692
# 0    646.312    399.14   8559820.259  2925.717  2393.835

# %%
rf_model(df_flu_symptoms_pre_COVID, weeks_to_predict=2, max_depth=2)
# Out:
# Shape of train_X: (233, 11)
# Shape of train_y: (233, 1)
# Shape of test_X: (2, 11)
# Shape of test_y: (2, 1)
# Train MSE: 207860.258
# Train RMSE: 455.917
# Train MAE: 283.864
# Test MSE: 424747.631
# Test RMSE: 651.727
# Test MAE: 650.498

# %%
rf_model(df_flu_symptoms_pre_COVID, weeks_to_predict=3, max_depth=2)
# Out:
# Shape of train_X: (232, 11)
# Shape of train_y: (232, 1)
# Shape of test_X: (3, 11)
# Shape of test_y: (3, 1)
# Train MSE: 208773.141
# Train RMSE: 456.917
# Train MAE: 285.484
# Test MSE: 295923.824
# Test RMSE: 543.989
# Test MAE: 513.751

# %%
rf_model(df_flu_symptoms_pre_COVID, weeks_to_predict=4, max_depth=2)
# Out:
# Shape of train_X: (231, 11)
# Shape of train_y: (231, 1)
# Shape of test_X: (4, 11)
# Shape of test_y: (4, 1)
# Train MSE: 214788.783
# Train RMSE: 463.453
# Train MAE: 288.606
# Test MSE: 243593.986
# Test RMSE: 493.552
# Test MAE: 468.207

# %%
rf_model(df_flu_symptoms_pre_COVID, weeks_to_predict=12, max_depth=2)
# Out:
# Shape of train_X: (223, 11)
# Shape of train_y: (223, 1)
# Shape of test_X: (12, 11)
# Shape of test_y: (12, 1)
# Train MSE: 206165.346
# Train RMSE: 454.054
# Train MAE: 281.549
# Test MSE: 343448.409
# Test RMSE: 586.045
# Test MAE: 481.409

# %%
rf_model(df_flu_symptoms_pre_COVID, weeks_to_predict=24, max_depth=2)
# Out:
# Shape of train_X: (211, 11)
# Shape of train_y: (211, 1)
# Shape of test_X: (24, 11)
# Shape of test_y: (24, 1)
# Train MSE: 188283.151
# Train RMSE: 433.916
# Train MAE: 273.013
# Test MSE: 639173.704
# Test RMSE: 799.483
# Test MAE: 534.23
