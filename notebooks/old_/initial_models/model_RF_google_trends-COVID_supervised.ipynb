# %% [markdown]
# # Imports

# %%
import pickle
import pandas as pd
import numpy as np

# regression models
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

# plotting
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
plt.rcParams['figure.figsize'] = [20, 10]

# custom functions
import sys
sys.path.append(r"C:\Users\User\Documents\projects\LHL_final_project_influenza_forecasting\src")
import rf_model

# %% [markdown]
# # Datasets

# %%
df_COVID_terms_pre_COVID = pickle.load(open(r"..\data\google_trend\df_COVID_terms_pre_COVID.pkl", "rb" ))
df_COVID_terms = pickle.load(open(r"..\data\google_trend\df_COVID_terms.pkl", "rb" ))

# %% [markdown]
# # Random Forest - pre-COVID

# %%
results_matrix = rf_model.rf_model(data=df_COVID_terms_pre_COVID, weeks_to_predict=1, max_depth=2, df_name='df_COVID_terms_pre_COVID')
# Out:
# Shape of train_X: (234, 7)
# Shape of train_y: (234, 1)
# Shape of test_X: (1, 7)
# Shape of test_y: (1, 1)

# %%
results_matrix
# Out:
#   Model                   Dataset Weeks-ahead Forecast    MSE_train  \
# 0    rf  df_COVID_terms_pre_COVID                    1  1284097.656
#
#   RMSE_train MAE_train    MSE_test RMSE_test MAE_test
# 0    1133.18   863.896  202574.741   450.083  450.083

# %%
results_matrix = rf_model.rf_model(data=df_COVID_terms_pre_COVID, weeks_to_predict=2, max_depth=2, df_name='df_COVID_terms_pre_COVID')
# Out:
# Shape of train_X: (233, 7)
# Shape of train_y: (233, 1)
# Shape of test_X: (2, 7)
# Shape of test_y: (2, 1)

# %%
results_matrix
# Out:
#   Model                   Dataset Weeks-ahead Forecast    MSE_train  \
# 0    rf  df_COVID_terms_pre_COVID                    1  1284097.656
# 0    rf  df_COVID_terms_pre_COVID                    2  1281098.556
#
#   RMSE_train MAE_train    MSE_test RMSE_test MAE_test
# 0    1133.18   863.896  202574.741   450.083  450.083
# 0   1131.856   864.074  261765.646    511.63  510.064

# %%
results_matrix = rf_model.rf_model(data=df_COVID_terms_pre_COVID, weeks_to_predict=3, max_depth=2, df_name='df_COVID_terms_pre_COVID')
# Out:
# Shape of train_X: (232, 7)
# Shape of train_y: (232, 1)
# Shape of test_X: (3, 7)
# Shape of test_y: (3, 1)

# %%
results_matrix
# Out:
#   Model                   Dataset Weeks-ahead Forecast    MSE_train  \
# 0    rf  df_COVID_terms_pre_COVID                    1  1284097.656
# 0    rf  df_COVID_terms_pre_COVID                    2  1281098.556
# 0    rf  df_COVID_terms_pre_COVID                    3  1263787.214
#
#   RMSE_train MAE_train    MSE_test RMSE_test MAE_test
# 0    1133.18   863.896  202574.741   450.083  450.083
# 0   1131.856   864.074  261765.646    511.63  510.064
# 0   1124.183   863.332  144140.878   379.659  334.898

# %%
results_matrix = rf_model.rf_model(data=df_COVID_terms_pre_COVID, weeks_to_predict=4, max_depth=2, df_name='df_COVID_terms_pre_COVID')
# Out:
# Shape of train_X: (231, 7)
# Shape of train_y: (231, 1)
# Shape of test_X: (4, 7)
# Shape of test_y: (4, 1)

# %%
results_matrix
# Out:
#   Model                   Dataset Weeks-ahead Forecast    MSE_train  \
# 0    rf  df_COVID_terms_pre_COVID                    1  1284097.656
# 0    rf  df_COVID_terms_pre_COVID                    2  1281098.556
# 0    rf  df_COVID_terms_pre_COVID                    3  1263787.214
# 0    rf  df_COVID_terms_pre_COVID                    4  1243927.645
#
#   RMSE_train MAE_train    MSE_test RMSE_test MAE_test
# 0    1133.18   863.896  202574.741   450.083  450.083
# 0   1131.856   864.074  261765.646    511.63  510.064
# 0   1124.183   863.332  144140.878   379.659  334.898
# 0   1115.315   861.737  327080.118   571.909  387.797

# %% [markdown]
# # Random Forest - post-COVID

# %%
results_matrix = rf_model.rf_model(data=df_COVID_terms, weeks_to_predict=1, max_depth=2, df_name='df_COVID_terms')
# Out:
# Shape of train_X: (376, 7)
# Shape of train_y: (376, 1)
# Shape of test_X: (1, 7)
# Shape of test_y: (1, 1)

# %%
results_matrix
# Out:
#   Model                   Dataset Weeks-ahead Forecast    MSE_train  \
# 0    rf  df_COVID_terms_pre_COVID                    1  1284097.656
# 0    rf  df_COVID_terms_pre_COVID                    2  1281098.556
# 0    rf  df_COVID_terms_pre_COVID                    3  1263787.214
# 0    rf  df_COVID_terms_pre_COVID                    4  1243927.645
# 0    rf            df_COVID_terms                    1   983371.642
#
#   RMSE_train MAE_train      MSE_test RMSE_test  MAE_test
# 0    1133.18   863.896    202574.741   450.083   450.083
# 0   1131.856   864.074    261765.646    511.63   510.064
# 0   1124.183   863.332    144140.878   379.659   334.898
# 0   1115.315   861.737    327080.118   571.909   387.797
# 0    991.651   682.959  18217137.404  4268.154  4268.154

# %%
results_matrix = rf_model.rf_model(data=df_COVID_terms, weeks_to_predict=2, max_depth=2, df_name='df_COVID_terms')
# Out:
# Shape of train_X: (375, 7)
# Shape of train_y: (375, 1)
# Shape of test_X: (2, 7)
# Shape of test_y: (2, 1)

# %%
results_matrix
# Out:
#   Model                   Dataset Weeks-ahead Forecast    MSE_train  \
# 0    rf  df_COVID_terms_pre_COVID                    1  1284097.656
# 0    rf  df_COVID_terms_pre_COVID                    2  1281098.556
# 0    rf  df_COVID_terms_pre_COVID                    3  1263787.214
# 0    rf  df_COVID_terms_pre_COVID                    4  1243927.645
# 0    rf            df_COVID_terms                    1   983371.642
# 0    rf            df_COVID_terms                    2   958233.029
#
#   RMSE_train MAE_train      MSE_test RMSE_test  MAE_test
# 0    1133.18   863.896    202574.741   450.083   450.083
# 0   1131.856   864.074    261765.646    511.63   510.064
# 0   1124.183   863.332    144140.878   379.659   334.898
# 0   1115.315   861.737    327080.118   571.909   387.797
# 0    991.651   682.959  18217137.404  4268.154  4268.154
# 0    978.894    672.53  15902387.801   3987.78  3933.119

# %%
results_matrix = rf_model.rf_model(data=df_COVID_terms, weeks_to_predict=3, max_depth=2, df_name='df_COVID_terms')
# Out:
# Shape of train_X: (374, 7)
# Shape of train_y: (374, 1)
# Shape of test_X: (3, 7)
# Shape of test_y: (3, 1)

# %%
results_matrix
# Out:
#   Model                   Dataset Weeks-ahead Forecast    MSE_train  \
# 0    rf  df_COVID_terms_pre_COVID                    1  1284097.656
# 0    rf  df_COVID_terms_pre_COVID                    2  1281098.556
# 0    rf  df_COVID_terms_pre_COVID                    3  1263787.214
# 0    rf  df_COVID_terms_pre_COVID                    4  1243927.645
# 0    rf            df_COVID_terms                    1   983371.642
# 0    rf            df_COVID_terms                    2   958233.029
# 0    rf            df_COVID_terms                    3   951315.944
#
#   RMSE_train MAE_train      MSE_test RMSE_test  MAE_test
# 0    1133.18   863.896    202574.741   450.083   450.083
# 0   1131.856   864.074    261765.646    511.63   510.064
# 0   1124.183   863.332    144140.878   379.659   334.898
# 0   1115.315   861.737    327080.118   571.909   387.797
# 0    991.651   682.959  18217137.404  4268.154  4268.154
# 0    978.894    672.53  15902387.801   3987.78  3933.119
# ...

# %%
results_matrix = rf_model.rf_model(data=df_COVID_terms, weeks_to_predict=4, max_depth=2, df_name='df_COVID_terms')
# Out:
# Shape of train_X: (373, 7)
# Shape of train_y: (373, 1)
# Shape of test_X: (4, 7)
# Shape of test_y: (4, 1)

# %%
results_matrix
# Out:
#   Model                   Dataset Weeks-ahead Forecast    MSE_train  \
# 0    rf  df_COVID_terms_pre_COVID                    1  1284097.656
# 0    rf  df_COVID_terms_pre_COVID                    2  1281098.556
# 0    rf  df_COVID_terms_pre_COVID                    3  1263787.214
# 0    rf  df_COVID_terms_pre_COVID                    4  1243927.645
# 0    rf            df_COVID_terms                    1   983371.642
# 0    rf            df_COVID_terms                    2   958233.029
# 0    rf            df_COVID_terms                    3   951315.944
# 0    rf            df_COVID_terms                    4   952351.794
#
#   RMSE_train MAE_train      MSE_test RMSE_test  MAE_test
# 0    1133.18   863.896    202574.741   450.083   450.083
# 0   1131.856   864.074    261765.646    511.63   510.064
# 0   1124.183   863.332    144140.878   379.659   334.898
# 0   1115.315   861.737    327080.118   571.909   387.797
# 0    991.651   682.959  18217137.404  4268.154  4268.154
# ...

# %%
pickle.dump(results_matrix, open(r"..\data\results_matrix_rf_COVID_terms.pkl", "wb" ))
