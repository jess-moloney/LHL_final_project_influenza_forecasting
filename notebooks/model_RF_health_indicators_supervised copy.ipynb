# %% [markdown]
# # Imports

# %%
import pickle
import pandas as pd
import numpy as np

# regression models
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

# plotting
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
plt.rcParams['figure.figsize'] = [20, 10]

# custom functions
import sys
sys.path.append(r"C:\Users\User\Documents\projects\LHL_final_project_influenza_forecasting\src")
from evaluate_model import *
from rf_model import *

# set random seed
seed_value = 2022

# %% [markdown]
# # Datasets

# %%
df_health_indicators_pre_COVID = pickle.load(open(r"..\data\health_indicators\df_health_indicators_pre_COVID.pkl", "rb" ))

# %% [markdown]
# # Random Forest - pre-COVID

# %%
rf_model(df_health_indicators_pre_COVID, weeks_to_predict=1, max_depth=2)
# Out:
# Shape of train_X: (217, 26)
# Shape of train_y: (217, 1)
# Shape of test_X: (1, 26)
# Shape of test_y: (1, 1)
# Test MSE: 218995.471
# Test RMSE: 467.97
# Test MAE: 467.97

# %%
rf_model(df_health_indicators_pre_COVID, weeks_to_predict=2, max_depth=2)
# Out:
# Shape of train_X: (216, 26)
# Shape of train_y: (216, 1)
# Shape of test_X: (2, 26)
# Shape of test_y: (2, 1)
# Test MSE: 246246.644
# Test RMSE: 496.232
# Test MAE: 494.618

# %%
rf_model(df_health_indicators_pre_COVID, weeks_to_predict=3, max_depth=2)
# Out:
# Shape of train_X: (215, 26)
# Shape of train_y: (215, 1)
# Shape of test_X: (3, 26)
# Shape of test_y: (3, 1)
# Test MSE: 182038.19
# Test RMSE: 426.659
# Test MAE: 387.368

# %%
rf_model(df_health_indicators_pre_COVID, weeks_to_predict=4, max_depth=2)
# Out:
# Shape of train_X: (214, 26)
# Shape of train_y: (214, 1)
# Shape of test_X: (4, 26)
# Shape of test_y: (4, 1)
# Test MSE: 185319.605
# Test RMSE: 430.488
# Test MAE: 377.298

# %%
rf_model(df_health_indicators_pre_COVID, weeks_to_predict=12, max_depth=2)
# Out:
# Shape of train_X: (206, 26)
# Shape of train_y: (206, 1)
# Shape of test_X: (12, 26)
# Shape of test_y: (12, 1)
# Test MSE: 7158102.13
# Test RMSE: 2675.463
# Test MAE: 2545.527

# %%
rf_model(df_health_indicators_pre_COVID, weeks_to_predict=24, max_depth=2)
# Out:
# Shape of train_X: (194, 26)
# Shape of train_y: (194, 1)
# Shape of test_X: (24, 26)
# Shape of test_y: (24, 1)
# Test MSE: 3670896.968
# Test RMSE: 1915.958
# Test MAE: 1591.805

# %%
rf_model(df_health_indicators_pre_COVID, weeks_to_predict=104, max_depth=2)
# Out:
# Shape of train_X: (114, 26)
# Shape of train_y: (114, 1)
# Shape of test_X: (104, 26)
# Shape of test_y: (104, 1)
# Test MSE: 10114223.607
# Test RMSE: 3180.287
# Test MAE: 2903.636
